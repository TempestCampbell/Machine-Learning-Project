# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# %%
# Dependencies
import numpy as np
import pandas as pd

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.4.0'

# %%
sonoma = pd.read_csv('sonomavalley.csv')
sonoma.head()
# Out:
#    Unnamed: 0  index      winery  vintage      cities  MarchLowTemp  \
# 0           5     14  Iron Horse     2009  Sebastopol     49.903226
# 1           6     15        Novy     2009  Healdsburg     41.548387
# 2           7     17  Iron Horse     2010  Sebastopol     52.935484
# 3           8     20  Iron Horse     2011  Sebastopol     50.806452
# 4           9     22  River Road     2011  Guttenberg     32.451613
#
#    MarchHighTemp  MarchAvgTemp  MarchPrecip  MarchCloudiness  ...  \
# 0      71.322581     63.258065          2.3        46.354839  ...
# 1      60.677419     53.193548          5.7        26.129032  ...
# 2      72.419355     64.903226          5.5        42.741935  ...
# 3      68.451613     61.677419          2.7        56.064516  ...
# 4      44.290323     39.580645          8.6        40.838710  ...
#
#    JulyAvgTemp  JulyPrecip  JulyCloudiness  JulyHumidity  AugLowTemp  \
# 0    47.129032         4.2       69.258065     87.322581   41.483871
# ...
