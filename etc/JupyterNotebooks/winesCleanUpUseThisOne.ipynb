# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import numpy as np
import pymysql
pymysql.install_as_MySQLdb()
import MySQLdb
import sqlalchemy
import sys, os, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

pw='postgres'

# %%
globalWineDF=pd.read_csv("../data/GlobalWinePoints.csv") 
globalWineDF
# Out:
#           vintage   country                           county  \
# 0      1919-01-01     Spain                             Cava
# 1      1929-01-01     Italy       Vernaccia di San Gimignano
# 2      1929-01-01     Italy  Sangiovese di Romagna Superiore
# 3      1934-01-01  Portugal                              NaN
# 4      1945-01-01    France                       Rivesaltes
# ...           ...       ...                              ...
# 24992  2016-01-01   Austria                              NaN
# 24993  2016-01-01   Austria                              NaN
# 24994  1821-01-01     Italy                         Prosecco
# 24995  1827-01-01     Spain                            Jerez
# 24996  1872-01-01     Spain                             Cava
#
#                            designation  points  price              province  \
# 0                   1919 Brut Selecció      88   13.0             Catalonia
# 1                                  NaN      87   14.0               Tuscany
# 2                             Prugneto      84   15.0         Central Italy
# 3                        Reserva Velho      93  495.0               Colares
# 4                       Legend Vintage      95  350.0  Languedoc-Roussillon
# ...                                ...     ...    ...                   ...
# 24992                     Lust & Laune      88   15.0      Niederösterreich
# 24993         Vorder Seiber Federspiel      90   25.0                Wachau
# 24994                  Cuvèe 1821 Brut      86   15.0                Veneto
# 24995  Pedro Ximenez 1827 Sweet Sherry      94   14.0             Andalucia
# 24996     Reserva Cuvée Barcelona 1872      85    NaN             Catalonia
#
#                                                    title           variety  \
# 0         L'Arboc NV 1919 Brut Selecció Sparkling (Cava)   Sparkling Blend
# 1             Guidi 1929 2015 Vernaccia di San Gimignano         Vernaccia
# 2      Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...        Sangiovese
# 3      Adega Viuva Gomes 1934 Reserva Velho Red (Cola...           Ramisco
# 4      Gérard Bertrand 1945 Legend Vintage Red (Rives...         Red Blend
# ...                                                  ...               ...
# 24992  Familie Zull 2016 Lust & Laune Rosé (Niederöst...              Rosé
# 24993  Jäger 2016 Vorder Seiber Federspiel Grüner Vel...  Grüner Veltliner
# 24994                Zonin NV Cuvèe 1821 Brut (Prosecco)             Glera
# 24995  Osborne NV Pedro Ximenez 1827 Sweet Sherry She...            Sherry
# 24996  Codorníu NV Reserva Cuvée Barcelona 1872 Spark...   Sparkling Blend
#
#                         winery
# 0                      L'Arboc
# 1                   Guidi 1929
# 2      Poderi dal Nespoli 1929
# 3            Adega Viuva Gomes
# 4              Gérard Bertrand
# ...                        ...
# 24992             Familie Zull
# 24993                    Jäger
# 24994                    Zonin
# 24995                  Osborne
# 24996                 Codorníu
#
# [24997 rows x 10 columns]

# %%
globalWineDF.dtypes
# Out:
# vintage         object
# country         object
# county          object
# designation     object
# points           int64
# price          float64
# province        object
# title           object
# variety         object
# winery          object
# dtype: object

# %%
# drop rows where the variety is NaN
globalWineDF = globalWineDF.dropna(how='any', subset=['variety'])
globalWineDF
# Out:
#           vintage   country                           county  \
# 0      1919-01-01     Spain                             Cava
# 1      1929-01-01     Italy       Vernaccia di San Gimignano
# 2      1929-01-01     Italy  Sangiovese di Romagna Superiore
# 3      1934-01-01  Portugal                              NaN
# 4      1945-01-01    France                       Rivesaltes
# ...           ...       ...                              ...
# 24992  2016-01-01   Austria                              NaN
# 24993  2016-01-01   Austria                              NaN
# 24994  1821-01-01     Italy                         Prosecco
# 24995  1827-01-01     Spain                            Jerez
# 24996  1872-01-01     Spain                             Cava
#
#                            designation  points  price              province  \
# 0                   1919 Brut Selecció      88   13.0             Catalonia
# 1                                  NaN      87   14.0               Tuscany
# 2                             Prugneto      84   15.0         Central Italy
# 3                        Reserva Velho      93  495.0               Colares
# 4                       Legend Vintage      95  350.0  Languedoc-Roussillon
# ...                                ...     ...    ...                   ...
# 24992                     Lust & Laune      88   15.0      Niederösterreich
# 24993         Vorder Seiber Federspiel      90   25.0                Wachau
# 24994                  Cuvèe 1821 Brut      86   15.0                Veneto
# 24995  Pedro Ximenez 1827 Sweet Sherry      94   14.0             Andalucia
# 24996     Reserva Cuvée Barcelona 1872      85    NaN             Catalonia
#
#                                                    title           variety  \
# 0         L'Arboc NV 1919 Brut Selecció Sparkling (Cava)   Sparkling Blend
# 1             Guidi 1929 2015 Vernaccia di San Gimignano         Vernaccia
# 2      Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...        Sangiovese
# 3      Adega Viuva Gomes 1934 Reserva Velho Red (Cola...           Ramisco
# 4      Gérard Bertrand 1945 Legend Vintage Red (Rives...         Red Blend
# ...                                                  ...               ...
# 24992  Familie Zull 2016 Lust & Laune Rosé (Niederöst...              Rosé
# 24993  Jäger 2016 Vorder Seiber Federspiel Grüner Vel...  Grüner Veltliner
# 24994                Zonin NV Cuvèe 1821 Brut (Prosecco)             Glera
# 24995  Osborne NV Pedro Ximenez 1827 Sweet Sherry She...            Sherry
# 24996  Codorníu NV Reserva Cuvée Barcelona 1872 Spark...   Sparkling Blend
#
#                         winery
# 0                      L'Arboc
# 1                   Guidi 1929
# 2      Poderi dal Nespoli 1929
# 3            Adega Viuva Gomes
# 4              Gérard Bertrand
# ...                        ...
# 24992             Familie Zull
# 24993                    Jäger
# 24994                    Zonin
# 24995                  Osborne
# 24996                 Codorníu
#
# [24997 rows x 10 columns]

# %%
# drop rows where the title is NaN
globalWineDF = globalWineDF.dropna(how='any', subset=['title'])
globalWineDF
# Out:
#           vintage   country                           county  \
# 0      1919-01-01     Spain                             Cava
# 1      1929-01-01     Italy       Vernaccia di San Gimignano
# 2      1929-01-01     Italy  Sangiovese di Romagna Superiore
# 3      1934-01-01  Portugal                              NaN
# 4      1945-01-01    France                       Rivesaltes
# ...           ...       ...                              ...
# 24992  2016-01-01   Austria                              NaN
# 24993  2016-01-01   Austria                              NaN
# 24994  1821-01-01     Italy                         Prosecco
# 24995  1827-01-01     Spain                            Jerez
# 24996  1872-01-01     Spain                             Cava
#
#                            designation  points  price              province  \
# 0                   1919 Brut Selecció      88   13.0             Catalonia
# 1                                  NaN      87   14.0               Tuscany
# 2                             Prugneto      84   15.0         Central Italy
# 3                        Reserva Velho      93  495.0               Colares
# 4                       Legend Vintage      95  350.0  Languedoc-Roussillon
# ...                                ...     ...    ...                   ...
# 24992                     Lust & Laune      88   15.0      Niederösterreich
# 24993         Vorder Seiber Federspiel      90   25.0                Wachau
# 24994                  Cuvèe 1821 Brut      86   15.0                Veneto
# 24995  Pedro Ximenez 1827 Sweet Sherry      94   14.0             Andalucia
# 24996     Reserva Cuvée Barcelona 1872      85    NaN             Catalonia
#
#                                                    title           variety  \
# 0         L'Arboc NV 1919 Brut Selecció Sparkling (Cava)   Sparkling Blend
# 1             Guidi 1929 2015 Vernaccia di San Gimignano         Vernaccia
# 2      Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...        Sangiovese
# 3      Adega Viuva Gomes 1934 Reserva Velho Red (Cola...           Ramisco
# 4      Gérard Bertrand 1945 Legend Vintage Red (Rives...         Red Blend
# ...                                                  ...               ...
# 24992  Familie Zull 2016 Lust & Laune Rosé (Niederöst...              Rosé
# 24993  Jäger 2016 Vorder Seiber Federspiel Grüner Vel...  Grüner Veltliner
# 24994                Zonin NV Cuvèe 1821 Brut (Prosecco)             Glera
# 24995  Osborne NV Pedro Ximenez 1827 Sweet Sherry She...            Sherry
# 24996  Codorníu NV Reserva Cuvée Barcelona 1872 Spark...   Sparkling Blend
#
#                         winery
# 0                      L'Arboc
# 1                   Guidi 1929
# 2      Poderi dal Nespoli 1929
# 3            Adega Viuva Gomes
# 4              Gérard Bertrand
# ...                        ...
# 24992             Familie Zull
# 24993                    Jäger
# 24994                    Zonin
# 24995                  Osborne
# 24996                 Codorníu
#
# [24997 rows x 10 columns]

# %%
globalWineDF['vintage']
# Out:
# 0        1919-01-01
# 1        1929-01-01
# 2        1929-01-01
# 3        1934-01-01
# 4        1945-01-01
#             ...
# 24992    2016-01-01
# 24993    2016-01-01
# 24994    1821-01-01
# 24995    1827-01-01
# 24996    1872-01-01
# Name: vintage, Length: 24997, dtype: object

# %%
# remove - to eventually convert to string
globalWineDF['vintage']=pd.to_numeric(globalWineDF.vintage.str.replace('-',''))
globalWineDF
# Out:
#         vintage   country                           county  \
# 0      19190101     Spain                             Cava
# 1      19290101     Italy       Vernaccia di San Gimignano
# 2      19290101     Italy  Sangiovese di Romagna Superiore
# 3      19340101  Portugal                              NaN
# 4      19450101    France                       Rivesaltes
# ...         ...       ...                              ...
# 24992  20160101   Austria                              NaN
# 24993  20160101   Austria                              NaN
# 24994  18210101     Italy                         Prosecco
# 24995  18270101     Spain                            Jerez
# 24996  18720101     Spain                             Cava
#
#                            designation  points  price              province  \
# 0                   1919 Brut Selecció      88   13.0             Catalonia
# 1                                  NaN      87   14.0               Tuscany
# 2                             Prugneto      84   15.0         Central Italy
# 3                        Reserva Velho      93  495.0               Colares
# 4                       Legend Vintage      95  350.0  Languedoc-Roussillon
# ...                                ...     ...    ...                   ...
# 24992                     Lust & Laune      88   15.0      Niederösterreich
# 24993         Vorder Seiber Federspiel      90   25.0                Wachau
# 24994                  Cuvèe 1821 Brut      86   15.0                Veneto
# 24995  Pedro Ximenez 1827 Sweet Sherry      94   14.0             Andalucia
# 24996     Reserva Cuvée Barcelona 1872      85    NaN             Catalonia
#
#                                                    title           variety  \
# 0         L'Arboc NV 1919 Brut Selecció Sparkling (Cava)   Sparkling Blend
# 1             Guidi 1929 2015 Vernaccia di San Gimignano         Vernaccia
# 2      Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...        Sangiovese
# 3      Adega Viuva Gomes 1934 Reserva Velho Red (Cola...           Ramisco
# 4      Gérard Bertrand 1945 Legend Vintage Red (Rives...         Red Blend
# ...                                                  ...               ...
# 24992  Familie Zull 2016 Lust & Laune Rosé (Niederöst...              Rosé
# 24993  Jäger 2016 Vorder Seiber Federspiel Grüner Vel...  Grüner Veltliner
# 24994                Zonin NV Cuvèe 1821 Brut (Prosecco)             Glera
# 24995  Osborne NV Pedro Ximenez 1827 Sweet Sherry She...            Sherry
# 24996  Codorníu NV Reserva Cuvée Barcelona 1872 Spark...   Sparkling Blend
#
#                         winery
# 0                      L'Arboc
# 1                   Guidi 1929
# 2      Poderi dal Nespoli 1929
# 3            Adega Viuva Gomes
# 4              Gérard Bertrand
# ...                        ...
# 24992             Familie Zull
# 24993                    Jäger
# 24994                    Zonin
# 24995                  Osborne
# 24996                 Codorníu
#
# [24997 rows x 10 columns]

# %%
# convert to string then keep first 4 characters
globalWineDF['vintage'] = globalWineDF.vintage.astype(str)
globalWineDF['vintage'] = globalWineDF['vintage'].str[:4]
globalWineDF
# Out:
#       vintage   country                           county  \
# 0        1919     Spain                             Cava
# 1        1929     Italy       Vernaccia di San Gimignano
# 2        1929     Italy  Sangiovese di Romagna Superiore
# 3        1934  Portugal                              NaN
# 4        1945    France                       Rivesaltes
# ...       ...       ...                              ...
# 24992    2016   Austria                              NaN
# 24993    2016   Austria                              NaN
# 24994    1821     Italy                         Prosecco
# 24995    1827     Spain                            Jerez
# 24996    1872     Spain                             Cava
#
#                            designation  points  price              province  \
# 0                   1919 Brut Selecció      88   13.0             Catalonia
# 1                                  NaN      87   14.0               Tuscany
# 2                             Prugneto      84   15.0         Central Italy
# 3                        Reserva Velho      93  495.0               Colares
# 4                       Legend Vintage      95  350.0  Languedoc-Roussillon
# ...                                ...     ...    ...                   ...
# 24992                     Lust & Laune      88   15.0      Niederösterreich
# 24993         Vorder Seiber Federspiel      90   25.0                Wachau
# 24994                  Cuvèe 1821 Brut      86   15.0                Veneto
# 24995  Pedro Ximenez 1827 Sweet Sherry      94   14.0             Andalucia
# 24996     Reserva Cuvée Barcelona 1872      85    NaN             Catalonia
#
#                                                    title           variety  \
# 0         L'Arboc NV 1919 Brut Selecció Sparkling (Cava)   Sparkling Blend
# 1             Guidi 1929 2015 Vernaccia di San Gimignano         Vernaccia
# 2      Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...        Sangiovese
# 3      Adega Viuva Gomes 1934 Reserva Velho Red (Cola...           Ramisco
# 4      Gérard Bertrand 1945 Legend Vintage Red (Rives...         Red Blend
# ...                                                  ...               ...
# 24992  Familie Zull 2016 Lust & Laune Rosé (Niederöst...              Rosé
# 24993  Jäger 2016 Vorder Seiber Federspiel Grüner Vel...  Grüner Veltliner
# 24994                Zonin NV Cuvèe 1821 Brut (Prosecco)             Glera
# 24995  Osborne NV Pedro Ximenez 1827 Sweet Sherry She...            Sherry
# 24996  Codorníu NV Reserva Cuvée Barcelona 1872 Spark...   Sparkling Blend
#
#                         winery
# 0                      L'Arboc
# 1                   Guidi 1929
# 2      Poderi dal Nespoli 1929
# 3            Adega Viuva Gomes
# 4              Gérard Bertrand
# ...                        ...
# 24992             Familie Zull
# 24993                    Jäger
# 24994                    Zonin
# 24995                  Osborne
# 24996                 Codorníu
#
# [24997 rows x 10 columns]

# %%
globalWineDF.dtypes
# Out:
# vintage         object
# country         object
# county          object
# designation     object
# points           int64
# price          float64
# province        object
# title           object
# variety         object
# winery          object
# dtype: object

# %%
# drop rows where the country is NaN
globalWineDF = globalWineDF.dropna(how='any', subset=['country'])
globalWineDF
# Out:
#       vintage   country                           county  \
# 0        1919     Spain                             Cava
# 1        1929     Italy       Vernaccia di San Gimignano
# 2        1929     Italy  Sangiovese di Romagna Superiore
# 3        1934  Portugal                              NaN
# 4        1945    France                       Rivesaltes
# ...       ...       ...                              ...
# 24992    2016   Austria                              NaN
# 24993    2016   Austria                              NaN
# 24994    1821     Italy                         Prosecco
# 24995    1827     Spain                            Jerez
# 24996    1872     Spain                             Cava
#
#                            designation  points  price              province  \
# 0                   1919 Brut Selecció      88   13.0             Catalonia
# 1                                  NaN      87   14.0               Tuscany
# 2                             Prugneto      84   15.0         Central Italy
# 3                        Reserva Velho      93  495.0               Colares
# 4                       Legend Vintage      95  350.0  Languedoc-Roussillon
# ...                                ...     ...    ...                   ...
# 24992                     Lust & Laune      88   15.0      Niederösterreich
# 24993         Vorder Seiber Federspiel      90   25.0                Wachau
# 24994                  Cuvèe 1821 Brut      86   15.0                Veneto
# 24995  Pedro Ximenez 1827 Sweet Sherry      94   14.0             Andalucia
# 24996     Reserva Cuvée Barcelona 1872      85    NaN             Catalonia
#
#                                                    title           variety  \
# 0         L'Arboc NV 1919 Brut Selecció Sparkling (Cava)   Sparkling Blend
# 1             Guidi 1929 2015 Vernaccia di San Gimignano         Vernaccia
# 2      Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...        Sangiovese
# 3      Adega Viuva Gomes 1934 Reserva Velho Red (Cola...           Ramisco
# 4      Gérard Bertrand 1945 Legend Vintage Red (Rives...         Red Blend
# ...                                                  ...               ...
# 24992  Familie Zull 2016 Lust & Laune Rosé (Niederöst...              Rosé
# 24993  Jäger 2016 Vorder Seiber Federspiel Grüner Vel...  Grüner Veltliner
# 24994                Zonin NV Cuvèe 1821 Brut (Prosecco)             Glera
# 24995  Osborne NV Pedro Ximenez 1827 Sweet Sherry She...            Sherry
# 24996  Codorníu NV Reserva Cuvée Barcelona 1872 Spark...   Sparkling Blend
#
#                         winery
# 0                      L'Arboc
# 1                   Guidi 1929
# 2      Poderi dal Nespoli 1929
# 3            Adega Viuva Gomes
# 4              Gérard Bertrand
# ...                        ...
# 24992             Familie Zull
# 24993                    Jäger
# 24994                    Zonin
# 24995                  Osborne
# 24996                 Codorníu
#
# [24989 rows x 10 columns]

# %%
# convert to string then keep first 4 characters
globalWineDF = globalWineDF.dropna(how='any', subset=['vintage'])
globalWineDF['vintage'] = globalWineDF.vintage.astype(int)
globalWineDF.dtypes
# Out:
# vintage          int32
# country         object
# county          object
# designation     object
# points           int64
# price          float64
# province        object
# title           object
# variety         object
# winery          object
# dtype: object

# %%
## drop any rows were title is a duplicate
globalWineDF=globalWineDF.drop_duplicates(['title'], keep='last')
globalWineDF
# Out:
#        vintage   country                           county  \
# 0         1919     Spain                             Cava
# 1         1929     Italy       Vernaccia di San Gimignano
# 2         1929     Italy  Sangiovese di Romagna Superiore
# 3         1934  Portugal                              NaN
# 4         1945    France                       Rivesaltes
# ...        ...       ...                              ...
# 24992     2016   Austria                              NaN
# 24993     2016   Austria                              NaN
# 24994     1821     Italy                         Prosecco
# 24995     1827     Spain                            Jerez
# 24996     1872     Spain                             Cava
#
#                            designation  points  price              province  \
# 0                   1919 Brut Selecció      88   13.0             Catalonia
# 1                                  NaN      87   14.0               Tuscany
# 2                             Prugneto      84   15.0         Central Italy
# 3                        Reserva Velho      93  495.0               Colares
# 4                       Legend Vintage      95  350.0  Languedoc-Roussillon
# ...                                ...     ...    ...                   ...
# 24992                     Lust & Laune      88   15.0      Niederösterreich
# 24993         Vorder Seiber Federspiel      90   25.0                Wachau
# 24994                  Cuvèe 1821 Brut      86   15.0                Veneto
# 24995  Pedro Ximenez 1827 Sweet Sherry      94   14.0             Andalucia
# 24996     Reserva Cuvée Barcelona 1872      85    NaN             Catalonia
#
#                                                    title           variety  \
# 0         L'Arboc NV 1919 Brut Selecció Sparkling (Cava)   Sparkling Blend
# 1             Guidi 1929 2015 Vernaccia di San Gimignano         Vernaccia
# 2      Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...        Sangiovese
# 3      Adega Viuva Gomes 1934 Reserva Velho Red (Cola...           Ramisco
# 4      Gérard Bertrand 1945 Legend Vintage Red (Rives...         Red Blend
# ...                                                  ...               ...
# 24992  Familie Zull 2016 Lust & Laune Rosé (Niederöst...              Rosé
# 24993  Jäger 2016 Vorder Seiber Federspiel Grüner Vel...  Grüner Veltliner
# 24994                Zonin NV Cuvèe 1821 Brut (Prosecco)             Glera
# 24995  Osborne NV Pedro Ximenez 1827 Sweet Sherry She...            Sherry
# 24996  Codorníu NV Reserva Cuvée Barcelona 1872 Spark...   Sparkling Blend
#
#                         winery
# 0                      L'Arboc
# 1                   Guidi 1929
# 2      Poderi dal Nespoli 1929
# 3            Adega Viuva Gomes
# 4              Gérard Bertrand
# ...                        ...
# 24992             Familie Zull
# 24993                    Jäger
# 24994                    Zonin
# 24995                  Osborne
# 24996                 Codorníu
#
# [24571 rows x 10 columns]

# %%
# saving the DataFrame as a CSV file 
globalWineCSV = globalWineDF.to_csv('../data/CleanedCSV/globalWineCleaned.csv', index = True)

# %%
#Create Engine and connection to Database
engine = create_engine(f'postgres://postgres:{pw}@localhost:5432/WineAndDined')
connection = engine.connect()

# %%
#Verify tables
engine.table_names()
# Out:
# ['winecheesepairingdata',
#  'wineries',
#  'wines',
#  'worldmeats',
#  'cheesedata',
#  'flavorlookups',
#  'cheeseflavors']

# %%
# Lowercase Dataframe columns in order to load
globalWineDF.columns = globalWineDF.columns.str.lower()

# %%
# Load Dataframe back into SQL
globalWineDF.to_sql(name='wines', con=engine, if_exists='append', index=False)
