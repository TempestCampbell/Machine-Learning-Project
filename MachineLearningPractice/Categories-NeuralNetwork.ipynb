# %%
# Dependencies
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
from sklearn import preprocessing
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.4.0'

# %%
# Read data
weather = pd.read_csv('Resources/dataLargerSet-Copy1.csv')
weather.head()
# Out:
#    Unnamed: 0  index                 winery  vintage  points           cities  \
# 0           0      6  Claiborne & Churchill     2009      88  San Luis Obispo
# 1           1      7  Claiborne & Churchill     2011      87  San Luis Obispo
# 2           2      8  Claiborne & Churchill     2013      94  San Luis Obispo
# 3           3      9  Claiborne & Churchill     2014      93  San Luis Obispo
# 4           4     10  Claiborne & Churchill     2014      91  San Luis Obispo
#
#    MarchLowTemp  MarchHighTemp  MarchAvgTemp  MarchPrecip  ...  JulyAvgTemp  \
# 0     42.129032      68.419355     58.580645          1.5  ...    82.935484
# 1     43.806452      62.161290     55.258065          9.4  ...    72.193548
# 2     47.354839      68.548387     60.516129          1.2  ...    73.129032
# 3     48.612903      68.322581     61.129032          1.8  ...    74.677419
# 4     48.612903      68.322581     61.129032          1.8  ...    74.677419
#
#    JulyPrecip  JulyCloudiness  JulyHumidity  AugLowTemp  AugHighTemp  \
# 0         0.0        2.612903     41.612903   56.741935    89.129032
# 1         0.1        1.838710     62.000000   61.741935    79.161290
# 2         0.2        5.322581     61.354839   61.290323    80.000000
# 3         0.3       10.032258     63.612903   62.096774    80.290323
# 4         0.3       10.032258     63.612903   62.096774    80.290323
#
#    AugAvgTemp  AugPrecip  AugCloudiness  AugHumidity
# 0   79.903226        0.1       4.419355    44.000000
# 1   73.806452        0.0       2.548387    57.000000
# 2   73.806452        0.0       2.516129    59.806452
# 3   73.967742        0.0       2.612903    63.774194
# 4   73.967742        0.0       2.612903    63.774194
#
# [5 rows x 42 columns]

# %%
# Clean data set
weatherClean=weather.drop(["Unnamed: 0", "index"], axis=1)
weatherClean.head()
# Out:
#                   winery  vintage  points           cities  MarchLowTemp  \
# 0  Claiborne & Churchill     2009      88  San Luis Obispo     42.129032
# 1  Claiborne & Churchill     2011      87  San Luis Obispo     43.806452
# 2  Claiborne & Churchill     2013      94  San Luis Obispo     47.354839
# 3  Claiborne & Churchill     2014      93  San Luis Obispo     48.612903
# 4  Claiborne & Churchill     2014      91  San Luis Obispo     48.612903
#
#    MarchHighTemp  MarchAvgTemp  MarchPrecip  MarchCloudiness  MarchHumidity  \
# 0      68.419355     58.580645          1.5        12.870968      61.387097
# 1      62.161290     55.258065          9.4        35.032258      76.903226
# 2      68.548387     60.516129          1.2        21.387097      61.677419
# 3      68.322581     61.129032          1.8        22.290323      64.258065
# 4      68.322581     61.129032          1.8        22.290323      64.258065
#
#    ...  JulyAvgTemp  JulyPrecip  JulyCloudiness  JulyHumidity  AugLowTemp  \
# 0  ...    82.935484         0.0        2.612903     41.612903   56.741935
# 1  ...    72.193548         0.1        1.838710     62.000000   61.741935
# 2  ...    73.129032         0.2        5.322581     61.354839   61.290323
# 3  ...    74.677419         0.3       10.032258     63.612903   62.096774
# 4  ...    74.677419         0.3       10.032258     63.612903   62.096774
#
#    AugHighTemp  AugAvgTemp  AugPrecip  AugCloudiness  AugHumidity
# 0    89.129032   79.903226        0.1       4.419355    44.000000
# 1    79.161290   73.806452        0.0       2.548387    57.000000
# 2    80.000000   73.806452        0.0       2.516129    59.806452
# 3    80.290323   73.967742        0.0       2.612903    63.774194
# 4    80.290323   73.967742        0.0       2.612903    63.774194
#
# [5 rows x 40 columns]

# %%
# Points into bins 'PointsRange'

bins = [0, 80, 85, 90, 95, 100]
names = ['<80','80-84', '85-89', '90-94', '95-100', '100+']

d = dict(enumerate(names, 1))

weatherClean['pointsRange'] = np.vectorize(d.get)(np.digitize(weatherClean['points'], bins))

weatherClean.head()
# Out:
#                   winery  vintage  points           cities  MarchLowTemp  \
# 0  Claiborne & Churchill     2009      88  San Luis Obispo     42.129032
# 1  Claiborne & Churchill     2011      87  San Luis Obispo     43.806452
# 2  Claiborne & Churchill     2013      94  San Luis Obispo     47.354839
# 3  Claiborne & Churchill     2014      93  San Luis Obispo     48.612903
# 4  Claiborne & Churchill     2014      91  San Luis Obispo     48.612903
#
#    MarchHighTemp  MarchAvgTemp  MarchPrecip  MarchCloudiness  MarchHumidity  \
# 0      68.419355     58.580645          1.5        12.870968      61.387097
# 1      62.161290     55.258065          9.4        35.032258      76.903226
# 2      68.548387     60.516129          1.2        21.387097      61.677419
# 3      68.322581     61.129032          1.8        22.290323      64.258065
# 4      68.322581     61.129032          1.8        22.290323      64.258065
#
#    ...  JulyPrecip  JulyCloudiness  JulyHumidity  AugLowTemp  AugHighTemp  \
# 0  ...         0.0        2.612903     41.612903   56.741935    89.129032
# 1  ...         0.1        1.838710     62.000000   61.741935    79.161290
# 2  ...         0.2        5.322581     61.354839   61.290323    80.000000
# 3  ...         0.3       10.032258     63.612903   62.096774    80.290323
# 4  ...         0.3       10.032258     63.612903   62.096774    80.290323
#
#    AugAvgTemp  AugPrecip  AugCloudiness  AugHumidity  pointsRange
# 0   79.903226        0.1       4.419355    44.000000        85-89
# 1   73.806452        0.0       2.548387    57.000000        85-89
# 2   73.806452        0.0       2.516129    59.806452        90-94
# 3   73.967742        0.0       2.612903    63.774194        90-94
# 4   73.967742        0.0       2.612903    63.774194        90-94
#
# [5 rows x 41 columns]

# %%
# Visualize data
weatherClean.drop_duplicates().pointsRange.value_counts()
# Out:
# 85-89     564
# 90-94     552
# 80-84      89
# 95-100     37
# Name: pointsRange, dtype: int64

# %%
# Visualize data
weatherClean.columns
# Out:
# Index(['winery', 'vintage', 'points', 'cities', 'MarchLowTemp',
#        'MarchHighTemp', 'MarchAvgTemp', 'MarchPrecip', 'MarchCloudiness',
#        'MarchHumidity', 'AprilLowTemp', 'AprilHighTemp', 'AprilAvgTemp',
#        'AprilPrecip', 'AprilCloudiness', 'AprilHumidity', 'MayLowTemp',
#        'MayHighTemp', 'MayAvgTemp', 'MayPrecip', 'MayCloudiness',
#        'MayHumidity', 'JuneLowTemp', 'JuneHighTemp', 'JuneAvgTemp',
#        'JunePrecip', 'JuneCloudiness', 'JuneHumidity', 'JulyLowTemp',
#        'JulyHighTemp', 'JulyAvgTemp', 'JulyPrecip', 'JulyCloudiness',
#        'JulyHumidity', 'AugLowTemp', 'AugHighTemp', 'AugAvgTemp', 'AugPrecip',
#        'AugCloudiness', 'AugHumidity', 'pointsRange'],
#       dtype='object')

# %%
# Apply ONE-HOT ENCODING

# Step 0: Reformat data
# weatherClean2 = weatherClean.values
# X = weatherClean2[:, 0:40]
# y = weatherClean2[:, 40]

# %%
# Data Pre-Processing
X= weatherClean.drop(['winery', 'vintage', 'points', 'cities','pointsRange'], axis=1)
y= weatherClean['pointsRange']


print(X.shape, y.shape)
# Out:
# (1328, 36) (1328,)

# %%
# # Step 1: Label-encode data set
# label_encoder = LabelEncoder()
# label_encoder.fit(y)
# encoded_y = label_encoder.transform(y)

# %%
# for label, original_class in zip(encoded_y, y):
#     print('Original Class: ' + str(original_class))
#     print('Encoded Label: ' + str(label))
#     print('-' * 12)

# %%
# # Step 2: One-hot encoding
# one_hot_y = to_categorical(encoded_y)
# one_hot_y

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, one_hot_y, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

print(X_train_scaled.shape, X_test_scaled.shape)
# Out:
# (996, 36) (332, 36)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

print(y_train_categorical.shape, y_test_categorical.shape)
# Out:
# (996, 4) (332, 4)

# %%
# Create Deep Learning Model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()

# model.add(LSTM(64, return_sequences=True,
#                input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))


model.add(Dense(units=100, activation='relu', input_dim=X_train_scaled.shape[1]))
model.add(Dense(units=100, activation='relu',input_dim=X_train_scaled.shape[1]))
model.add(Dense(units=4, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=250,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/200
# 32/32 - 1s - loss: 0.7493 - accuracy: 0.6295
# Epoch 2/200
# 32/32 - 0s - loss: 0.7394 - accuracy: 0.6325
# Epoch 3/200
# 32/32 - 0s - loss: 0.7382 - accuracy: 0.6456
# Epoch 4/200
# 32/32 - 0s - loss: 0.7421 - accuracy: 0.6476
# Epoch 5/200
# 32/32 - 0s - loss: 0.7499 - accuracy: 0.6416
# Epoch 6/200
# 32/32 - 0s - loss: 0.7372 - accuracy: 0.6315
# Epoch 7/200
# 32/32 - 0s - loss: 0.7360 - accuracy: 0.6436
# Epoch 8/200
# 32/32 - 0s - loss: 0.7469 - accuracy: 0.6365
# Epoch 9/200
# 32/32 - 0s - loss: 0.7378 - accuracy: 0.6416
# Epoch 10/200
# 32/32 - 0s - loss: 0.7403 - accuracy: 0.6496
# Epoch 11/200
# 32/32 - 0s - loss: 0.7396 - accuracy: 0.6456
# Epoch 12/200
# 32/32 - 0s - loss: 0.7436 - accuracy: 0.6436
# Epoch 13/200
# 32/32 - 0s - loss: 0.7361 - accuracy: 0.6446
# Epoch 14/200
# 32/32 - 0s - loss: 0.7511 - accuracy: 0.6355
# Epoch 15/200
# 32/32 - 0s - loss: 0.7372 - accuracy: 0.6396
# Epoch 16/200
# 32/32 - 0s - loss: 0.7336 - accuracy: 0.6376
# Epoch 17/200
# 32/32 - 0s - loss: 0.7522 - accuracy: 0.6446
# Epoch 18/200
# 32/32 - 0s - loss: 0.7424 - accuracy: 0.6355
# Epoch 19/200
# 32/32 - 0s - loss: 0.7503 - accuracy: 0.6436
# Epoch 20/200
# 32/32 - 0s - loss: 0.7398 - accuracy: 0.6446
# Epoch 21/200
# 32/32 - 0s - loss: 0.7444 - accuracy: 0.6476
# Epoch 22/200
# 32/32 - 0s - loss: 0.7366 - accuracy: 0.6486
# Epoch 23/200
# 32/32 - 0s - loss: 0.7374 - accuracy: 0.6526
# Epoch 24/200
# 32/32 - 0s - loss: 0.7373 - accuracy: 0.6506
# Epoch 25/200
# 32/32 - 0s - loss: 0.7324 - accuracy: 0.6436
# Epoch 26/200
# 32/32 - 0s - loss: 0.7337 - accuracy: 0.6406
# Epoch 27/200
# 32/32 - 0s - loss: 0.7434 - accuracy: 0.6506
# Epoch 28/200
# 32/32 - 0s - loss: 0.7384 - accuracy: 0.6386
# Epoch 29/200
# 32/32 - 0s - loss: 0.7340 - accuracy: 0.6476
# Epoch 30/200
# 32/32 - 0s - loss: 0.7356 - accuracy: 0.6506
# Epoch 31/200
# 32/32 - 0s - loss: 0.7345 - accuracy: 0.6386
# Epoch 32/200
# 32/32 - 0s - loss: 0.7414 - accuracy: 0.6406
# Epoch 33/200
# 32/32 - 0s - loss: 0.7459 - accuracy: 0.6536
# Epoch 34/200
# 32/32 - 0s - loss: 0.7403 - accuracy: 0.6516
# Epoch 35/200
# 32/32 - 0s - loss: 0.7387 - accuracy: 0.6516
# Epoch 36/200
# 32/32 - 0s - loss: 0.7350 - accuracy: 0.6376
# Epoch 37/200
# 32/32 - 0s - loss: 0.7490 - accuracy: 0.6426
# Epoch 38/200
# 32/32 - 0s - loss: 0.7458 - accuracy: 0.6355
# Epoch 39/200
# 32/32 - 0s - loss: 0.7401 - accuracy: 0.6396
# Epoch 40/200
# 32/32 - 0s - loss: 0.7382 - accuracy: 0.6345
# Epoch 41/200
# 32/32 - 0s - loss: 0.7422 - accuracy: 0.6365
# Epoch 42/200
# 32/32 - 0s - loss: 0.7443 - accuracy: 0.6406
# Epoch 43/200
# 32/32 - 0s - loss: 0.7349 - accuracy: 0.6466
# Epoch 44/200
# 32/32 - 0s - loss: 0.7417 - accuracy: 0.6355
# Epoch 45/200
# 32/32 - 0s - loss: 0.7320 - accuracy: 0.6506
# Epoch 46/200
# 32/32 - 0s - loss: 0.7374 - accuracy: 0.6476
# Epoch 47/200
# 32/32 - 0s - loss: 0.7360 - accuracy: 0.6456
# Epoch 48/200
# 32/32 - 0s - loss: 0.7437 - accuracy: 0.6325
# Epoch 49/200
# 32/32 - 0s - loss: 0.7429 - accuracy: 0.6345
# Epoch 50/200
# 32/32 - 0s - loss: 0.7404 - accuracy: 0.6325
# Epoch 51/200
# 32/32 - 0s - loss: 0.7307 - accuracy: 0.6496
# Epoch 52/200
# 32/32 - 0s - loss: 0.7378 - accuracy: 0.6426
# Epoch 53/200
# 32/32 - 0s - loss: 0.7694 - accuracy: 0.6285
# Epoch 54/200
# 32/32 - 0s - loss: 0.7487 - accuracy: 0.6386
# Epoch 55/200
# 32/32 - 0s - loss: 0.7516 - accuracy: 0.6295
# Epoch 56/200
# 32/32 - 0s - loss: 0.7510 - accuracy: 0.6516
# Epoch 57/200
# 32/32 - 0s - loss: 0.7328 - accuracy: 0.6456
# Epoch 58/200
# 32/32 - 0s - loss: 0.7360 - accuracy: 0.6345
# Epoch 59/200
# 32/32 - 0s - loss: 0.7393 - accuracy: 0.6456
# Epoch 60/200
# 32/32 - 0s - loss: 0.7374 - accuracy: 0.6466
# Epoch 61/200
# 32/32 - 0s - loss: 0.7384 - accuracy: 0.6496
# Epoch 62/200
# 32/32 - 0s - loss: 0.7384 - accuracy: 0.6596
# Epoch 63/200
# 32/32 - 0s - loss: 0.7419 - accuracy: 0.6235
# Epoch 64/200
# 32/32 - 0s - loss: 0.7429 - accuracy: 0.6396
# Epoch 65/200
# 32/32 - 0s - loss: 0.7351 - accuracy: 0.6325
# Epoch 66/200
# 32/32 - 0s - loss: 0.7376 - accuracy: 0.6365
# Epoch 67/200
# 32/32 - 0s - loss: 0.7384 - accuracy: 0.6446
# Epoch 68/200
# 32/32 - 0s - loss: 0.7391 - accuracy: 0.6406
# Epoch 69/200
# 32/32 - 0s - loss: 0.7393 - accuracy: 0.6335
# Epoch 70/200
# 32/32 - 0s - loss: 0.7362 - accuracy: 0.6476
# Epoch 71/200
# 32/32 - 0s - loss: 0.7395 - accuracy: 0.6406
# Epoch 72/200
# 32/32 - 0s - loss: 0.7367 - accuracy: 0.6396
# Epoch 73/200
# 32/32 - 0s - loss: 0.7312 - accuracy: 0.6506
# Epoch 74/200
# 32/32 - 0s - loss: 0.7374 - accuracy: 0.6536
# Epoch 75/200
# 32/32 - 0s - loss: 0.7357 - accuracy: 0.6506
# Epoch 76/200
# 32/32 - 0s - loss: 0.7319 - accuracy: 0.6496
# Epoch 77/200
# 32/32 - 0s - loss: 0.7371 - accuracy: 0.6456
# Epoch 78/200
# 32/32 - 0s - loss: 0.7403 - accuracy: 0.6496
# Epoch 79/200
# 32/32 - 0s - loss: 0.7326 - accuracy: 0.6516
# Epoch 80/200
# 32/32 - 0s - loss: 0.7346 - accuracy: 0.6365
# Epoch 81/200
# 32/32 - 0s - loss: 0.7367 - accuracy: 0.6345
# Epoch 82/200
# 32/32 - 0s - loss: 0.7460 - accuracy: 0.6386
# Epoch 83/200
# 32/32 - 0s - loss: 0.7359 - accuracy: 0.6516
# Epoch 84/200
# 32/32 - 0s - loss: 0.7404 - accuracy: 0.6566
# Epoch 85/200
# 32/32 - 0s - loss: 0.7420 - accuracy: 0.6496
# Epoch 86/200
# 32/32 - 0s - loss: 0.7413 - accuracy: 0.6536
# Epoch 87/200
# 32/32 - 0s - loss: 0.7346 - accuracy: 0.6526
# Epoch 88/200
# 32/32 - 0s - loss: 0.7336 - accuracy: 0.6406
# Epoch 89/200
# 32/32 - 0s - loss: 0.7400 - accuracy: 0.6305
# Epoch 90/200
# 32/32 - 0s - loss: 0.7407 - accuracy: 0.6386
# Epoch 91/200
# 32/32 - 0s - loss: 0.7433 - accuracy: 0.6325
# Epoch 92/200
# 32/32 - 0s - loss: 0.7275 - accuracy: 0.6526
# Epoch 93/200
# 32/32 - 0s - loss: 0.7397 - accuracy: 0.6396
# Epoch 94/200
# 32/32 - 0s - loss: 0.7347 - accuracy: 0.6396
# Epoch 95/200
# 32/32 - 0s - loss: 0.7383 - accuracy: 0.6376
# Epoch 96/200
# 32/32 - 0s - loss: 0.7426 - accuracy: 0.6416
# Epoch 97/200
# 32/32 - 0s - loss: 0.7504 - accuracy: 0.6315
# Epoch 98/200
# 32/32 - 0s - loss: 0.7412 - accuracy: 0.6386
# Epoch 99/200
# 32/32 - 0s - loss: 0.7401 - accuracy: 0.6396
# Epoch 100/200
# 32/32 - 0s - loss: 0.7406 - accuracy: 0.6436
# Epoch 101/200
# 32/32 - 0s - loss: 0.7405 - accuracy: 0.6376
# Epoch 102/200
# 32/32 - 0s - loss: 0.7465 - accuracy: 0.6235
# Epoch 103/200
# 32/32 - 0s - loss: 0.7313 - accuracy: 0.6426
# Epoch 104/200
# 32/32 - 0s - loss: 0.7354 - accuracy: 0.6476
# Epoch 105/200
# 32/32 - 0s - loss: 0.7307 - accuracy: 0.6476
# Epoch 106/200
# 32/32 - 0s - loss: 0.7458 - accuracy: 0.6345
# Epoch 107/200
# 32/32 - 0s - loss: 0.7361 - accuracy: 0.6526
# Epoch 108/200
# 32/32 - 0s - loss: 0.7463 - accuracy: 0.6426
# Epoch 109/200
# 32/32 - 0s - loss: 0.7482 - accuracy: 0.6365
# Epoch 110/200
# 32/32 - 0s - loss: 0.7378 - accuracy: 0.6345
# Epoch 111/200
# 32/32 - 0s - loss: 0.7316 - accuracy: 0.6426
# Epoch 112/200
# 32/32 - 0s - loss: 0.7334 - accuracy: 0.6406
# Epoch 113/200
# 32/32 - 0s - loss: 0.7371 - accuracy: 0.6396
# Epoch 114/200
# 32/32 - 0s - loss: 0.7342 - accuracy: 0.6436
# Epoch 115/200
# 32/32 - 0s - loss: 0.7329 - accuracy: 0.6376
# Epoch 116/200
# 32/32 - 0s - loss: 0.7446 - accuracy: 0.6526
# Epoch 117/200
# 32/32 - 0s - loss: 0.7412 - accuracy: 0.6406
# Epoch 118/200
# 32/32 - 0s - loss: 0.7358 - accuracy: 0.6516
# Epoch 119/200
# 32/32 - 0s - loss: 0.7418 - accuracy: 0.6426
# Epoch 120/200
# 32/32 - 0s - loss: 0.7354 - accuracy: 0.6396
# Epoch 121/200
# 32/32 - 0s - loss: 0.7341 - accuracy: 0.6466
# Epoch 122/200
# 32/32 - 0s - loss: 0.7324 - accuracy: 0.6426
# Epoch 123/200
# 32/32 - 0s - loss: 0.7423 - accuracy: 0.6355
# Epoch 124/200
# 32/32 - 0s - loss: 0.7419 - accuracy: 0.6376
# Epoch 125/200
# 32/32 - 0s - loss: 0.7384 - accuracy: 0.6365
# Epoch 126/200
# 32/32 - 0s - loss: 0.7362 - accuracy: 0.6406
# Epoch 127/200
# 32/32 - 0s - loss: 0.7399 - accuracy: 0.6426
# Epoch 128/200
# 32/32 - 0s - loss: 0.7330 - accuracy: 0.6416
# Epoch 129/200
# 32/32 - 0s - loss: 0.7340 - accuracy: 0.6466
# Epoch 130/200
# 32/32 - 0s - loss: 0.7542 - accuracy: 0.6496
# Epoch 131/200
# 32/32 - 0s - loss: 0.7326 - accuracy: 0.6406
# Epoch 132/200
# 32/32 - 0s - loss: 0.7515 - accuracy: 0.6315
# Epoch 133/200
# 32/32 - 0s - loss: 0.7301 - accuracy: 0.6416
# Epoch 134/200
# 32/32 - 0s - loss: 0.7416 - accuracy: 0.6496
# Epoch 135/200
# 32/32 - 0s - loss: 0.7356 - accuracy: 0.6496
# Epoch 136/200
# 32/32 - 0s - loss: 0.7400 - accuracy: 0.6386
# Epoch 137/200
# 32/32 - 0s - loss: 0.7344 - accuracy: 0.6486
# Epoch 138/200
# 32/32 - 0s - loss: 0.7472 - accuracy: 0.6436
# Epoch 139/200
# 32/32 - 0s - loss: 0.7400 - accuracy: 0.6386
# Epoch 140/200
# 32/32 - 0s - loss: 0.7326 - accuracy: 0.6426
# Epoch 141/200
# 32/32 - 0s - loss: 0.7388 - accuracy: 0.6466
# Epoch 142/200
# 32/32 - 0s - loss: 0.7324 - accuracy: 0.6486
# Epoch 143/200
# 32/32 - 0s - loss: 0.7320 - accuracy: 0.6426
# Epoch 144/200
# 32/32 - 0s - loss: 0.7323 - accuracy: 0.6446
# Epoch 145/200
# 32/32 - 0s - loss: 0.7331 - accuracy: 0.6416
# Epoch 146/200
# 32/32 - 0s - loss: 0.7446 - accuracy: 0.6376
# Epoch 147/200
# 32/32 - 0s - loss: 0.7457 - accuracy: 0.6436
# Epoch 148/200
# 32/32 - 0s - loss: 0.7446 - accuracy: 0.6365
# Epoch 149/200
# 32/32 - 0s - loss: 0.7423 - accuracy: 0.6365
# Epoch 150/200
# 32/32 - 0s - loss: 0.7303 - accuracy: 0.6546
# Epoch 151/200
# 32/32 - 0s - loss: 0.7422 - accuracy: 0.6376
# Epoch 152/200
# 32/32 - 0s - loss: 0.7287 - accuracy: 0.6456
# Epoch 153/200
# 32/32 - 0s - loss: 0.7374 - accuracy: 0.6456
# Epoch 154/200
# 32/32 - 0s - loss: 0.7341 - accuracy: 0.6456
# Epoch 155/200
# 32/32 - 0s - loss: 0.7403 - accuracy: 0.6396
# Epoch 156/200
# 32/32 - 0s - loss: 0.7419 - accuracy: 0.6396
# Epoch 157/200
# 32/32 - 0s - loss: 0.7458 - accuracy: 0.6476
# Epoch 158/200
# 32/32 - 0s - loss: 0.7380 - accuracy: 0.6496
# Epoch 159/200
# 32/32 - 0s - loss: 0.7324 - accuracy: 0.6516
# Epoch 160/200
# 32/32 - 0s - loss: 0.7330 - accuracy: 0.6406
# Epoch 161/200
# 32/32 - 0s - loss: 0.7461 - accuracy: 0.6295
# Epoch 162/200
# 32/32 - 0s - loss: 0.7442 - accuracy: 0.6165
# Epoch 163/200
# 32/32 - 0s - loss: 0.7363 - accuracy: 0.6355
# Epoch 164/200
# 32/32 - 0s - loss: 0.7315 - accuracy: 0.6536
# Epoch 165/200
# 32/32 - 0s - loss: 0.7317 - accuracy: 0.6426
# Epoch 166/200
# 32/32 - 0s - loss: 0.7350 - accuracy: 0.6496
# Epoch 167/200
# 32/32 - 0s - loss: 0.7374 - accuracy: 0.6486
# Epoch 168/200
# 32/32 - 0s - loss: 0.7352 - accuracy: 0.6285
# Epoch 169/200
# 32/32 - 0s - loss: 0.7317 - accuracy: 0.6456
# Epoch 170/200
# 32/32 - 0s - loss: 0.7402 - accuracy: 0.6406
# Epoch 171/200
# 32/32 - 0s - loss: 0.7327 - accuracy: 0.6506
# Epoch 172/200
# 32/32 - 0s - loss: 0.7395 - accuracy: 0.6466
# Epoch 173/200
# 32/32 - 0s - loss: 0.7397 - accuracy: 0.6386
# Epoch 174/200
# 32/32 - 0s - loss: 0.7420 - accuracy: 0.6406
# Epoch 175/200
# 32/32 - 0s - loss: 0.7376 - accuracy: 0.6466
# Epoch 176/200
# 32/32 - 0s - loss: 0.7321 - accuracy: 0.6436
# Epoch 177/200
# 32/32 - 0s - loss: 0.7335 - accuracy: 0.6426
# Epoch 178/200
# 32/32 - 0s - loss: 0.7253 - accuracy: 0.6556
# Epoch 179/200
# 32/32 - 0s - loss: 0.7353 - accuracy: 0.6466
# Epoch 180/200
# 32/32 - 0s - loss: 0.7327 - accuracy: 0.6416
# Epoch 181/200
# 32/32 - 0s - loss: 0.7316 - accuracy: 0.6496
# Epoch 182/200
# 32/32 - 0s - loss: 0.7290 - accuracy: 0.6396
# Epoch 183/200
# 32/32 - 0s - loss: 0.7331 - accuracy: 0.6476
# Epoch 184/200
# 32/32 - 0s - loss: 0.7320 - accuracy: 0.6446
# Epoch 185/200
# 32/32 - 0s - loss: 0.7354 - accuracy: 0.6335
# Epoch 186/200
# 32/32 - 0s - loss: 0.7315 - accuracy: 0.6426
# Epoch 187/200
# 32/32 - 0s - loss: 0.7359 - accuracy: 0.6446
# Epoch 188/200
# 32/32 - 0s - loss: 0.7400 - accuracy: 0.6365
# Epoch 189/200
# 32/32 - 0s - loss: 0.7363 - accuracy: 0.6386
# Epoch 190/200
# 32/32 - 0s - loss: 0.7421 - accuracy: 0.6426
# Epoch 191/200
# 32/32 - 0s - loss: 0.7360 - accuracy: 0.6376
# Epoch 192/200
# 32/32 - 0s - loss: 0.7300 - accuracy: 0.6386
# Epoch 193/200
# 32/32 - 0s - loss: 0.7379 - accuracy: 0.6426
# Epoch 194/200
# 32/32 - 0s - loss: 0.7292 - accuracy: 0.6486
# Epoch 195/200
# 32/32 - 0s - loss: 0.7290 - accuracy: 0.6446
# Epoch 196/200
# 32/32 - 0s - loss: 0.7282 - accuracy: 0.6406
# Epoch 197/200
# 32/32 - 0s - loss: 0.7369 - accuracy: 0.6376
# Epoch 198/200
# 32/32 - 0s - loss: 0.7382 - accuracy: 0.6365
# Epoch 199/200
# 32/32 - 0s - loss: 0.7369 - accuracy: 0.6526
# Epoch 200/200
# 32/32 - 0s - loss: 0.7305 - accuracy: 0.6486

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 11/11 - 0s - loss: 1.1466 - accuracy: 0.5693
# Normal Neural Network - Loss: 1.1465834379196167, Accuracy: 0.5692771077156067

# %%
encoded_predictions = model.predict_classes(X_test_scaled)
prediction_labels = label_encoder.inverse_transform(encoded_predictions).tolist()

# %%
y_test1=y_test.tolist()

# print(type(y_test1))
# print(y_test1)

# %%
#Compare 

numRight= 0
for n in range (0, len(prediction_labels)):
    if prediction_labels[n]== y_test1[n]:
        numRight += 1   
print(numRight, (100*numRight/len(y_test1)))
# Out:
# 189 56.9277108433735

# %%
dfAccur=pd.DataFrame( )
dfAccur["y_test"]= y_test
dfAccur["y_predictions"]= prediction_labels
dfAccur.head(100)
# Out:
#      y_test y_predictions
# 452   90-94         85-89
# 705   90-94         90-94
# 989   85-89         90-94
# 115   85-89         85-89
# 1152  85-89         85-89
# ...     ...           ...
# 321   85-89         90-94
# 1231  90-94         90-94
# 1047  85-89         90-94
# 111   85-89         85-89
# 1117  85-89         90-94
#
# [100 rows x 2 columns]

# %%
df = pd.DataFrame({'Real Values':sc_y.inverse_transform(y_test.reshape(-1)), 'Predicted Values':y_pred})
df
