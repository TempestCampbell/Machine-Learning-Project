# %%
# Dependencies
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
from sklearn import preprocessing
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.4.0'

# %%
# Read data
weather = pd.read_csv('Resources/dataLargerSet-Copy1.csv')
weather.head()
# Out:
#    Unnamed: 0  index                 winery  vintage  points           cities  \
# 0           0      6  Claiborne & Churchill     2009      88  San Luis Obispo
# 1           1      7  Claiborne & Churchill     2011      87  San Luis Obispo
# 2           2      8  Claiborne & Churchill     2013      94  San Luis Obispo
# 3           3      9  Claiborne & Churchill     2014      93  San Luis Obispo
# 4           4     10  Claiborne & Churchill     2014      91  San Luis Obispo
#
#    MarchLowTemp  MarchHighTemp  MarchAvgTemp  MarchPrecip  ...  JulyAvgTemp  \
# 0     42.129032      68.419355     58.580645          1.5  ...    82.935484
# 1     43.806452      62.161290     55.258065          9.4  ...    72.193548
# 2     47.354839      68.548387     60.516129          1.2  ...    73.129032
# 3     48.612903      68.322581     61.129032          1.8  ...    74.677419
# 4     48.612903      68.322581     61.129032          1.8  ...    74.677419
#
#    JulyPrecip  JulyCloudiness  JulyHumidity  AugLowTemp  AugHighTemp  \
# 0         0.0        2.612903     41.612903   56.741935    89.129032
# 1         0.1        1.838710     62.000000   61.741935    79.161290
# 2         0.2        5.322581     61.354839   61.290323    80.000000
# 3         0.3       10.032258     63.612903   62.096774    80.290323
# 4         0.3       10.032258     63.612903   62.096774    80.290323
#
#    AugAvgTemp  AugPrecip  AugCloudiness  AugHumidity
# 0   79.903226        0.1       4.419355    44.000000
# 1   73.806452        0.0       2.548387    57.000000
# 2   73.806452        0.0       2.516129    59.806452
# 3   73.967742        0.0       2.612903    63.774194
# 4   73.967742        0.0       2.612903    63.774194
#
# [5 rows x 42 columns]

# %%
# Clean data set
weatherClean=weather.drop(["Unnamed: 0", "index"], axis=1)
weatherClean.head()
# Out:
#                   winery  vintage  points           cities  MarchLowTemp  \
# 0  Claiborne & Churchill     2009      88  San Luis Obispo     42.129032
# 1  Claiborne & Churchill     2011      87  San Luis Obispo     43.806452
# 2  Claiborne & Churchill     2013      94  San Luis Obispo     47.354839
# 3  Claiborne & Churchill     2014      93  San Luis Obispo     48.612903
# 4  Claiborne & Churchill     2014      91  San Luis Obispo     48.612903
#
#    MarchHighTemp  MarchAvgTemp  MarchPrecip  MarchCloudiness  MarchHumidity  \
# 0      68.419355     58.580645          1.5        12.870968      61.387097
# 1      62.161290     55.258065          9.4        35.032258      76.903226
# 2      68.548387     60.516129          1.2        21.387097      61.677419
# 3      68.322581     61.129032          1.8        22.290323      64.258065
# 4      68.322581     61.129032          1.8        22.290323      64.258065
#
#    ...  JulyAvgTemp  JulyPrecip  JulyCloudiness  JulyHumidity  AugLowTemp  \
# 0  ...    82.935484         0.0        2.612903     41.612903   56.741935
# 1  ...    72.193548         0.1        1.838710     62.000000   61.741935
# 2  ...    73.129032         0.2        5.322581     61.354839   61.290323
# 3  ...    74.677419         0.3       10.032258     63.612903   62.096774
# 4  ...    74.677419         0.3       10.032258     63.612903   62.096774
#
#    AugHighTemp  AugAvgTemp  AugPrecip  AugCloudiness  AugHumidity
# 0    89.129032   79.903226        0.1       4.419355    44.000000
# 1    79.161290   73.806452        0.0       2.548387    57.000000
# 2    80.000000   73.806452        0.0       2.516129    59.806452
# 3    80.290323   73.967742        0.0       2.612903    63.774194
# 4    80.290323   73.967742        0.0       2.612903    63.774194
#
# [5 rows x 40 columns]

# %%
# Points into bins 'PointsRange'
bins = [0, 80, 85, 90, 95, 100]
names = ['<80','80-84', '85-89', '90-94', '95-100', '100+']

d = dict(enumerate(names, 1))

weatherClean['pointsRange'] = np.vectorize(d.get)(np.digitize(weatherClean['points'], bins))

weatherClean.head()
# Out:
#                   winery  vintage  points           cities  MarchLowTemp  \
# 0  Claiborne & Churchill     2009      88  San Luis Obispo     42.129032
# 1  Claiborne & Churchill     2011      87  San Luis Obispo     43.806452
# 2  Claiborne & Churchill     2013      94  San Luis Obispo     47.354839
# 3  Claiborne & Churchill     2014      93  San Luis Obispo     48.612903
# 4  Claiborne & Churchill     2014      91  San Luis Obispo     48.612903
#
#    MarchHighTemp  MarchAvgTemp  MarchPrecip  MarchCloudiness  MarchHumidity  \
# 0      68.419355     58.580645          1.5        12.870968      61.387097
# 1      62.161290     55.258065          9.4        35.032258      76.903226
# 2      68.548387     60.516129          1.2        21.387097      61.677419
# 3      68.322581     61.129032          1.8        22.290323      64.258065
# 4      68.322581     61.129032          1.8        22.290323      64.258065
#
#    ...  JulyPrecip  JulyCloudiness  JulyHumidity  AugLowTemp  AugHighTemp  \
# 0  ...         0.0        2.612903     41.612903   56.741935    89.129032
# 1  ...         0.1        1.838710     62.000000   61.741935    79.161290
# 2  ...         0.2        5.322581     61.354839   61.290323    80.000000
# 3  ...         0.3       10.032258     63.612903   62.096774    80.290323
# 4  ...         0.3       10.032258     63.612903   62.096774    80.290323
#
#    AugAvgTemp  AugPrecip  AugCloudiness  AugHumidity  pointsRange
# 0   79.903226        0.1       4.419355    44.000000        85-89
# 1   73.806452        0.0       2.548387    57.000000        85-89
# 2   73.806452        0.0       2.516129    59.806452        90-94
# 3   73.967742        0.0       2.612903    63.774194        90-94
# 4   73.967742        0.0       2.612903    63.774194        90-94
#
# [5 rows x 41 columns]

# %%
# Visualize data: Data points dispersion into bins/categories
weatherClean.drop_duplicates().pointsRange.value_counts()
# Out:
# 85-89     564
# 90-94     552
# 80-84      89
# 95-100     37
# Name: pointsRange, dtype: int64

# %%
# Visualize data: Check Column names
weatherClean.columns
# Out:
# Index(['winery', 'vintage', 'points', 'cities', 'MarchLowTemp',
#        'MarchHighTemp', 'MarchAvgTemp', 'MarchPrecip', 'MarchCloudiness',
#        'MarchHumidity', 'AprilLowTemp', 'AprilHighTemp', 'AprilAvgTemp',
#        'AprilPrecip', 'AprilCloudiness', 'AprilHumidity', 'MayLowTemp',
#        'MayHighTemp', 'MayAvgTemp', 'MayPrecip', 'MayCloudiness',
#        'MayHumidity', 'JuneLowTemp', 'JuneHighTemp', 'JuneAvgTemp',
#        'JunePrecip', 'JuneCloudiness', 'JuneHumidity', 'JulyLowTemp',
#        'JulyHighTemp', 'JulyAvgTemp', 'JulyPrecip', 'JulyCloudiness',
#        'JulyHumidity', 'AugLowTemp', 'AugHighTemp', 'AugAvgTemp', 'AugPrecip',
#        'AugCloudiness', 'AugHumidity', 'pointsRange'],
#       dtype='object')

# %%
# Data Pre-Processing: Create X and y values for machine learning
X= weatherClean.drop(['winery', 'vintage', 'points', 'cities','pointsRange'], axis=1)
y= weatherClean['pointsRange']

print(X.shape, y.shape)
# Out:
# (1328, 36) (1328,)

# %%
#Split x-values into training(20%) and testing(80%) cohorts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)
#Scale data to create normalization
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

#Check scaled shape of each data set 
print(X_train_scaled.shape, X_test_scaled.shape)
# Out:
# (996, 36) (332, 36)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding, four categories
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

print(y_train_categorical.shape, y_test_categorical.shape)
# Out:
# (996, 4) (332, 4)

# %%
# Create Deep Learning Model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()

# model.add(LSTM(64, return_sequences=True,
#                input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))


model.add(Dense(units=100, activation='relu', input_dim=X_train_scaled.shape[1]))
model.add(Dense(units=100, activation='relu',input_dim=X_train_scaled.shape[1]))
model.add(Dense(units=4, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=250,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/250
# 32/32 - 1s - loss: 1.1250 - accuracy: 0.4187
# Epoch 2/250
# 32/32 - 0s - loss: 1.0315 - accuracy: 0.4629
# Epoch 3/250
# 32/32 - 0s - loss: 1.0203 - accuracy: 0.4689
# Epoch 4/250
# 32/32 - 0s - loss: 1.0136 - accuracy: 0.4900
# Epoch 5/250
# 32/32 - 0s - loss: 1.0072 - accuracy: 0.5131
# Epoch 6/250
# 32/32 - 0s - loss: 1.0048 - accuracy: 0.5131
# Epoch 7/250
# 32/32 - 0s - loss: 1.0044 - accuracy: 0.5171
# Epoch 8/250
# 32/32 - 0s - loss: 0.9986 - accuracy: 0.5030
# Epoch 9/250
# 32/32 - 0s - loss: 0.9975 - accuracy: 0.5161
# Epoch 10/250
# 32/32 - 0s - loss: 0.9912 - accuracy: 0.5432
# Epoch 11/250
# 32/32 - 0s - loss: 1.0030 - accuracy: 0.4970
# Epoch 12/250
# 32/32 - 0s - loss: 0.9952 - accuracy: 0.5291
# Epoch 13/250
# 32/32 - 0s - loss: 0.9942 - accuracy: 0.5181
# Epoch 14/250
# 32/32 - 0s - loss: 0.9853 - accuracy: 0.5382
# Epoch 15/250
# 32/32 - 0s - loss: 0.9848 - accuracy: 0.5472
# Epoch 16/250
# 32/32 - 0s - loss: 0.9846 - accuracy: 0.5432
# Epoch 17/250
# 32/32 - 0s - loss: 0.9837 - accuracy: 0.5361
# Epoch 18/250
# 32/32 - 0s - loss: 0.9803 - accuracy: 0.5522
# Epoch 19/250
# 32/32 - 0s - loss: 0.9757 - accuracy: 0.5542
# Epoch 20/250
# 32/32 - 0s - loss: 0.9775 - accuracy: 0.5522
# Epoch 21/250
# 32/32 - 0s - loss: 0.9713 - accuracy: 0.5572
# Epoch 22/250
# 32/32 - 0s - loss: 0.9717 - accuracy: 0.5462
# Epoch 23/250
# 32/32 - 0s - loss: 0.9720 - accuracy: 0.5422
# Epoch 24/250
# 32/32 - 0s - loss: 0.9776 - accuracy: 0.5552
# Epoch 25/250
# 32/32 - 0s - loss: 0.9638 - accuracy: 0.5673
# Epoch 26/250
# 32/32 - 0s - loss: 0.9720 - accuracy: 0.5602
# Epoch 27/250
# 32/32 - 0s - loss: 0.9803 - accuracy: 0.5402
# Epoch 28/250
# 32/32 - 0s - loss: 0.9627 - accuracy: 0.5542
# Epoch 29/250
# 32/32 - 0s - loss: 0.9661 - accuracy: 0.5622
# Epoch 30/250
# 32/32 - 0s - loss: 0.9622 - accuracy: 0.5602
# Epoch 31/250
# 32/32 - 0s - loss: 0.9761 - accuracy: 0.5482
# Epoch 32/250
# 32/32 - 0s - loss: 0.9596 - accuracy: 0.5693
# Epoch 33/250
# 32/32 - 0s - loss: 0.9566 - accuracy: 0.5693
# Epoch 34/250
# 32/32 - 0s - loss: 0.9617 - accuracy: 0.5562
# Epoch 35/250
# 32/32 - 0s - loss: 0.9645 - accuracy: 0.5532
# Epoch 36/250
# 32/32 - 0s - loss: 0.9580 - accuracy: 0.5733
# Epoch 37/250
# 32/32 - 0s - loss: 0.9533 - accuracy: 0.5733
# Epoch 38/250
# 32/32 - 0s - loss: 0.9568 - accuracy: 0.5643
# Epoch 39/250
# 32/32 - 0s - loss: 0.9565 - accuracy: 0.5522
# Epoch 40/250
# 32/32 - 0s - loss: 0.9533 - accuracy: 0.5562
# Epoch 41/250
# 32/32 - 0s - loss: 0.9538 - accuracy: 0.5733
# Epoch 42/250
# 32/32 - 0s - loss: 0.9499 - accuracy: 0.5653
# Epoch 43/250
# 32/32 - 0s - loss: 0.9466 - accuracy: 0.5693
# Epoch 44/250
# 32/32 - 0s - loss: 0.9606 - accuracy: 0.5462
# Epoch 45/250
# 32/32 - 0s - loss: 0.9440 - accuracy: 0.5763
# Epoch 46/250
# 32/32 - 0s - loss: 0.9478 - accuracy: 0.5743
# Epoch 47/250
# 32/32 - 0s - loss: 0.9514 - accuracy: 0.5673
# Epoch 48/250
# 32/32 - 0s - loss: 0.9469 - accuracy: 0.5763
# Epoch 49/250
# 32/32 - 0s - loss: 0.9549 - accuracy: 0.5602
# Epoch 50/250
# 32/32 - 0s - loss: 0.9479 - accuracy: 0.5602
# Epoch 51/250
# 32/32 - 0s - loss: 0.9432 - accuracy: 0.5823
# Epoch 52/250
# 32/32 - 0s - loss: 0.9353 - accuracy: 0.5833
# Epoch 53/250
# 32/32 - 0s - loss: 0.9370 - accuracy: 0.5813
# Epoch 54/250
# 32/32 - 0s - loss: 0.9420 - accuracy: 0.5823
# Epoch 55/250
# 32/32 - 0s - loss: 0.9365 - accuracy: 0.5803
# Epoch 56/250
# 32/32 - 0s - loss: 0.9470 - accuracy: 0.5663
# Epoch 57/250
# 32/32 - 0s - loss: 0.9371 - accuracy: 0.5713
# Epoch 58/250
# 32/32 - 0s - loss: 0.9420 - accuracy: 0.5683
# Epoch 59/250
# 32/32 - 0s - loss: 0.9334 - accuracy: 0.5773
# Epoch 60/250
# 32/32 - 0s - loss: 0.9377 - accuracy: 0.5803
# Epoch 61/250
# 32/32 - 0s - loss: 0.9365 - accuracy: 0.5633
# Epoch 62/250
# 32/32 - 0s - loss: 0.9292 - accuracy: 0.5773
# Epoch 63/250
# 32/32 - 0s - loss: 0.9336 - accuracy: 0.5783
# Epoch 64/250
# 32/32 - 0s - loss: 0.9359 - accuracy: 0.5833
# Epoch 65/250
# 32/32 - 0s - loss: 0.9308 - accuracy: 0.5813
# Epoch 66/250
# 32/32 - 0s - loss: 0.9284 - accuracy: 0.5723
# Epoch 67/250
# 32/32 - 0s - loss: 0.9310 - accuracy: 0.5793
# Epoch 68/250
# 32/32 - 0s - loss: 0.9280 - accuracy: 0.5873
# Epoch 69/250
# 32/32 - 0s - loss: 0.9325 - accuracy: 0.5723
# Epoch 70/250
# 32/32 - 0s - loss: 0.9348 - accuracy: 0.5592
# Epoch 71/250
# 32/32 - 0s - loss: 0.9240 - accuracy: 0.5733
# Epoch 72/250
# 32/32 - 0s - loss: 0.9272 - accuracy: 0.5703
# Epoch 73/250
# 32/32 - 0s - loss: 0.9239 - accuracy: 0.5643
# Epoch 74/250
# 32/32 - 0s - loss: 0.9218 - accuracy: 0.5843
# Epoch 75/250
# 32/32 - 0s - loss: 0.9262 - accuracy: 0.5783
# Epoch 76/250
# 32/32 - 0s - loss: 0.9253 - accuracy: 0.5833
# Epoch 77/250
# 32/32 - 0s - loss: 0.9262 - accuracy: 0.5823
# Epoch 78/250
# 32/32 - 0s - loss: 0.9194 - accuracy: 0.5853
# Epoch 79/250
# 32/32 - 0s - loss: 0.9216 - accuracy: 0.5964
# Epoch 80/250
# 32/32 - 0s - loss: 0.9177 - accuracy: 0.5743
# Epoch 81/250
# 32/32 - 0s - loss: 0.9177 - accuracy: 0.5924
# Epoch 82/250
# 32/32 - 0s - loss: 0.9212 - accuracy: 0.5683
# Epoch 83/250
# 32/32 - 0s - loss: 0.9340 - accuracy: 0.5633
# Epoch 84/250
# 32/32 - 0s - loss: 0.9273 - accuracy: 0.5813
# Epoch 85/250
# 32/32 - 0s - loss: 0.9229 - accuracy: 0.5843
# Epoch 86/250
# 32/32 - 0s - loss: 0.9189 - accuracy: 0.5873
# Epoch 87/250
# 32/32 - 0s - loss: 0.9227 - accuracy: 0.5813
# Epoch 88/250
# 32/32 - 0s - loss: 0.9144 - accuracy: 0.5914
# Epoch 89/250
# 32/32 - 0s - loss: 0.9138 - accuracy: 0.5924
# Epoch 90/250
# 32/32 - 0s - loss: 0.9273 - accuracy: 0.5733
# Epoch 91/250
# 32/32 - 0s - loss: 0.9178 - accuracy: 0.5964
# Epoch 92/250
# 32/32 - 0s - loss: 0.9193 - accuracy: 0.5914
# Epoch 93/250
# 32/32 - 0s - loss: 0.9170 - accuracy: 0.5823
# Epoch 94/250
# 32/32 - 0s - loss: 0.9046 - accuracy: 0.5823
# Epoch 95/250
# 32/32 - 0s - loss: 0.9121 - accuracy: 0.5944
# Epoch 96/250
# 32/32 - 0s - loss: 0.9153 - accuracy: 0.5793
# Epoch 97/250
# 32/32 - 0s - loss: 0.9102 - accuracy: 0.5894
# Epoch 98/250
# 32/32 - 0s - loss: 0.9084 - accuracy: 0.5833
# Epoch 99/250
# 32/32 - 0s - loss: 0.9063 - accuracy: 0.5833
# Epoch 100/250
# 32/32 - 0s - loss: 0.9105 - accuracy: 0.5873
# Epoch 101/250
# 32/32 - 0s - loss: 0.9163 - accuracy: 0.5703
# Epoch 102/250
# 32/32 - 0s - loss: 0.9126 - accuracy: 0.5863
# Epoch 103/250
# 32/32 - 0s - loss: 0.9088 - accuracy: 0.5853
# Epoch 104/250
# 32/32 - 0s - loss: 0.9055 - accuracy: 0.5833
# Epoch 105/250
# 32/32 - 0s - loss: 0.9044 - accuracy: 0.5924
# Epoch 106/250
# 32/32 - 0s - loss: 0.9118 - accuracy: 0.5753
# Epoch 107/250
# 32/32 - 0s - loss: 0.9058 - accuracy: 0.5904
# Epoch 108/250
# 32/32 - 0s - loss: 0.9064 - accuracy: 0.5823
# Epoch 109/250
# 32/32 - 0s - loss: 0.9213 - accuracy: 0.5743
# Epoch 110/250
# 32/32 - 0s - loss: 0.9022 - accuracy: 0.5823
# Epoch 111/250
# 32/32 - 0s - loss: 0.9044 - accuracy: 0.5873
# Epoch 112/250
# 32/32 - 0s - loss: 0.9019 - accuracy: 0.5873
# Epoch 113/250
# 32/32 - 0s - loss: 0.9056 - accuracy: 0.5894
# Epoch 114/250
# 32/32 - 0s - loss: 0.9042 - accuracy: 0.5914
# Epoch 115/250
# 32/32 - 0s - loss: 0.9141 - accuracy: 0.5823
# Epoch 116/250
# 32/32 - 0s - loss: 0.9036 - accuracy: 0.5863
# Epoch 117/250
# 32/32 - 0s - loss: 0.8958 - accuracy: 0.5914
# Epoch 118/250
# 32/32 - 0s - loss: 0.9024 - accuracy: 0.6044
# Epoch 119/250
# 32/32 - 0s - loss: 0.9047 - accuracy: 0.5863
# Epoch 120/250
# 32/32 - 0s - loss: 0.9046 - accuracy: 0.5833
# Epoch 121/250
# 32/32 - 0s - loss: 0.9035 - accuracy: 0.5853
# Epoch 122/250
# 32/32 - 0s - loss: 0.8982 - accuracy: 0.5843
# Epoch 123/250
# 32/32 - 0s - loss: 0.8976 - accuracy: 0.5763
# Epoch 124/250
# 32/32 - 0s - loss: 0.8971 - accuracy: 0.5904
# Epoch 125/250
# 32/32 - 0s - loss: 0.9021 - accuracy: 0.5843
# Epoch 126/250
# 32/32 - 0s - loss: 0.8942 - accuracy: 0.5944
# Epoch 127/250
# 32/32 - 0s - loss: 0.9075 - accuracy: 0.5753
# Epoch 128/250
# 32/32 - 0s - loss: 0.9004 - accuracy: 0.5853
# Epoch 129/250
# 32/32 - 0s - loss: 0.9057 - accuracy: 0.5693
# Epoch 130/250
# 32/32 - 0s - loss: 0.9044 - accuracy: 0.5813
# Epoch 131/250
# 32/32 - 0s - loss: 0.9034 - accuracy: 0.5853
# Epoch 132/250
# 32/32 - 0s - loss: 0.9037 - accuracy: 0.5803
# Epoch 133/250
# 32/32 - 0s - loss: 0.9087 - accuracy: 0.5713
# Epoch 134/250
# 32/32 - 0s - loss: 0.8966 - accuracy: 0.5924
# Epoch 135/250
# 32/32 - 0s - loss: 0.9024 - accuracy: 0.5733
# Epoch 136/250
# 32/32 - 0s - loss: 0.8967 - accuracy: 0.5863
# Epoch 137/250
# 32/32 - 0s - loss: 0.8917 - accuracy: 0.5894
# Epoch 138/250
# 32/32 - 0s - loss: 0.8914 - accuracy: 0.6004
# Epoch 139/250
# 32/32 - 0s - loss: 0.8951 - accuracy: 0.5743
# Epoch 140/250
# 32/32 - 0s - loss: 0.9000 - accuracy: 0.5793
# Epoch 141/250
# 32/32 - 0s - loss: 0.8918 - accuracy: 0.5863
# Epoch 142/250
# 32/32 - 0s - loss: 0.8975 - accuracy: 0.5863
# Epoch 143/250
# 32/32 - 0s - loss: 0.8921 - accuracy: 0.5894
# Epoch 144/250
# 32/32 - 0s - loss: 0.8973 - accuracy: 0.5803
# Epoch 145/250
# 32/32 - 0s - loss: 0.8866 - accuracy: 0.5924
# Epoch 146/250
# 32/32 - 0s - loss: 0.8949 - accuracy: 0.5904
# Epoch 147/250
# 32/32 - 0s - loss: 0.8943 - accuracy: 0.5934
# Epoch 148/250
# 32/32 - 0s - loss: 0.8906 - accuracy: 0.5894
# Epoch 149/250
# 32/32 - 0s - loss: 0.8939 - accuracy: 0.5873
# Epoch 150/250
# 32/32 - 0s - loss: 0.8930 - accuracy: 0.5994
# Epoch 151/250
# 32/32 - 0s - loss: 0.8875 - accuracy: 0.5984
# Epoch 152/250
# 32/32 - 0s - loss: 0.9008 - accuracy: 0.5944
# Epoch 153/250
# 32/32 - 0s - loss: 0.8923 - accuracy: 0.5884
# Epoch 154/250
# 32/32 - 0s - loss: 0.9021 - accuracy: 0.5733
# Epoch 155/250
# 32/32 - 0s - loss: 0.8898 - accuracy: 0.5904
# Epoch 156/250
# 32/32 - 0s - loss: 0.8859 - accuracy: 0.5884
# Epoch 157/250
# 32/32 - 0s - loss: 0.8877 - accuracy: 0.6084
# Epoch 158/250
# 32/32 - 0s - loss: 0.8926 - accuracy: 0.5944
# Epoch 159/250
# 32/32 - 0s - loss: 0.8847 - accuracy: 0.6014
# Epoch 160/250
# 32/32 - 0s - loss: 0.8875 - accuracy: 0.5863
# Epoch 161/250
# 32/32 - 0s - loss: 0.8951 - accuracy: 0.5873
# Epoch 162/250
# 32/32 - 0s - loss: 0.8930 - accuracy: 0.5793
# Epoch 163/250
# 32/32 - 0s - loss: 0.8844 - accuracy: 0.6004
# Epoch 164/250
# 32/32 - 0s - loss: 0.8955 - accuracy: 0.5823
# Epoch 165/250
# 32/32 - 0s - loss: 0.8884 - accuracy: 0.5873
# Epoch 166/250
# 32/32 - 0s - loss: 0.8851 - accuracy: 0.5863
# Epoch 167/250
# 32/32 - 0s - loss: 0.8837 - accuracy: 0.5894
# Epoch 168/250
# 32/32 - 0s - loss: 0.8838 - accuracy: 0.5914
# Epoch 169/250
# 32/32 - 0s - loss: 0.8795 - accuracy: 0.5984
# Epoch 170/250
# 32/32 - 0s - loss: 0.8862 - accuracy: 0.5974
# Epoch 171/250
# 32/32 - 0s - loss: 0.8877 - accuracy: 0.5984
# Epoch 172/250
# 32/32 - 0s - loss: 0.8846 - accuracy: 0.5944
# Epoch 173/250
# 32/32 - 0s - loss: 0.8860 - accuracy: 0.5934
# Epoch 174/250
# 32/32 - 0s - loss: 0.8865 - accuracy: 0.5884
# Epoch 175/250
# 32/32 - 0s - loss: 0.8879 - accuracy: 0.5974
# Epoch 176/250
# 32/32 - 0s - loss: 0.8884 - accuracy: 0.5853
# Epoch 177/250
# 32/32 - 0s - loss: 0.8759 - accuracy: 0.6034
# Epoch 178/250
# 32/32 - 0s - loss: 0.8841 - accuracy: 0.5954
# Epoch 179/250
# 32/32 - 0s - loss: 0.8781 - accuracy: 0.6014
# Epoch 180/250
# 32/32 - 0s - loss: 0.8896 - accuracy: 0.5793
# Epoch 181/250
# 32/32 - 0s - loss: 0.8861 - accuracy: 0.5944
# Epoch 182/250
# 32/32 - 0s - loss: 0.8838 - accuracy: 0.5743
# Epoch 183/250
# 32/32 - 0s - loss: 0.8807 - accuracy: 0.5863
# Epoch 184/250
# 32/32 - 0s - loss: 0.8787 - accuracy: 0.5934
# Epoch 185/250
# 32/32 - 0s - loss: 0.8719 - accuracy: 0.5873
# Epoch 186/250
# 32/32 - 0s - loss: 0.8753 - accuracy: 0.5974
# Epoch 187/250
# 32/32 - 0s - loss: 0.8880 - accuracy: 0.5783
# Epoch 188/250
# 32/32 - 0s - loss: 0.8720 - accuracy: 0.5894
# Epoch 189/250
# 32/32 - 0s - loss: 0.8842 - accuracy: 0.5944
# Epoch 190/250
# 32/32 - 0s - loss: 0.8880 - accuracy: 0.5833
# Epoch 191/250
# 32/32 - 0s - loss: 0.8729 - accuracy: 0.6014
# Epoch 192/250
# 32/32 - 0s - loss: 0.8677 - accuracy: 0.5984
# Epoch 193/250
# 32/32 - 0s - loss: 0.8777 - accuracy: 0.5914
# Epoch 194/250
# 32/32 - 0s - loss: 0.8837 - accuracy: 0.5964
# Epoch 195/250
# 32/32 - 0s - loss: 0.8776 - accuracy: 0.5763
# Epoch 196/250
# 32/32 - 0s - loss: 0.8713 - accuracy: 0.6084
# Epoch 197/250
# 32/32 - 0s - loss: 0.8693 - accuracy: 0.6004
# Epoch 198/250
# 32/32 - 0s - loss: 0.8705 - accuracy: 0.5924
# Epoch 199/250
# 32/32 - 0s - loss: 0.8697 - accuracy: 0.6024
# Epoch 200/250
# 32/32 - 0s - loss: 0.8655 - accuracy: 0.5974
# Epoch 201/250
# 32/32 - 0s - loss: 0.8685 - accuracy: 0.6155
# Epoch 202/250
# 32/32 - 0s - loss: 0.8786 - accuracy: 0.6074
# Epoch 203/250
# 32/32 - 0s - loss: 0.8741 - accuracy: 0.6024
# Epoch 204/250
# 32/32 - 0s - loss: 0.8685 - accuracy: 0.5924
# Epoch 205/250
# 32/32 - 0s - loss: 0.8771 - accuracy: 0.5914
# Epoch 206/250
# 32/32 - 0s - loss: 0.8729 - accuracy: 0.5873
# Epoch 207/250
# 32/32 - 0s - loss: 0.8647 - accuracy: 0.5984
# Epoch 208/250
# 32/32 - 0s - loss: 0.8705 - accuracy: 0.5994
# Epoch 209/250
# 32/32 - 0s - loss: 0.8668 - accuracy: 0.6114
# Epoch 210/250
# 32/32 - 0s - loss: 0.8701 - accuracy: 0.6054
# Epoch 211/250
# 32/32 - 0s - loss: 0.8671 - accuracy: 0.5964
# Epoch 212/250
# 32/32 - 0s - loss: 0.8676 - accuracy: 0.6014
# Epoch 213/250
# 32/32 - 0s - loss: 0.8602 - accuracy: 0.6084
# Epoch 214/250
# 32/32 - 0s - loss: 0.8748 - accuracy: 0.6034
# Epoch 215/250
# 32/32 - 0s - loss: 0.8652 - accuracy: 0.6114
# Epoch 216/250
# 32/32 - 0s - loss: 0.8646 - accuracy: 0.5934
# Epoch 217/250
# 32/32 - 0s - loss: 0.8671 - accuracy: 0.5813
# Epoch 218/250
# 32/32 - 0s - loss: 0.8645 - accuracy: 0.6004
# Epoch 219/250
# 32/32 - 0s - loss: 0.8583 - accuracy: 0.6034
# Epoch 220/250
# 32/32 - 0s - loss: 0.8605 - accuracy: 0.5863
# Epoch 221/250
# 32/32 - 0s - loss: 0.8710 - accuracy: 0.6004
# Epoch 222/250
# 32/32 - 0s - loss: 0.8686 - accuracy: 0.5884
# Epoch 223/250
# 32/32 - 0s - loss: 0.8605 - accuracy: 0.5964
# Epoch 224/250
# 32/32 - 0s - loss: 0.8562 - accuracy: 0.6024
# Epoch 225/250
# 32/32 - 0s - loss: 0.8664 - accuracy: 0.5894
# Epoch 226/250
# 32/32 - 0s - loss: 0.8696 - accuracy: 0.5894
# Epoch 227/250
# 32/32 - 0s - loss: 0.8663 - accuracy: 0.5994
# Epoch 228/250
# 32/32 - 0s - loss: 0.8607 - accuracy: 0.5954
# Epoch 229/250
# 32/32 - 0s - loss: 0.8636 - accuracy: 0.6084
# Epoch 230/250
# 32/32 - 0s - loss: 0.8655 - accuracy: 0.5884
# Epoch 231/250
# 32/32 - 0s - loss: 0.8642 - accuracy: 0.5894
# Epoch 232/250
# 32/32 - 0s - loss: 0.8526 - accuracy: 0.5994
# Epoch 233/250
# 32/32 - 0s - loss: 0.8536 - accuracy: 0.6034
# Epoch 234/250
# 32/32 - 0s - loss: 0.8615 - accuracy: 0.5984
# Epoch 235/250
# 32/32 - 0s - loss: 0.8706 - accuracy: 0.5974
# Epoch 236/250
# 32/32 - 0s - loss: 0.8549 - accuracy: 0.5984
# Epoch 237/250
# 32/32 - 0s - loss: 0.8616 - accuracy: 0.6054
# Epoch 238/250
# 32/32 - 0s - loss: 0.8583 - accuracy: 0.5924
# Epoch 239/250
# 32/32 - 0s - loss: 0.8544 - accuracy: 0.5994
# Epoch 240/250
# 32/32 - 0s - loss: 0.8582 - accuracy: 0.5994
# Epoch 241/250
# 32/32 - 0s - loss: 0.8632 - accuracy: 0.6034
# Epoch 242/250
# 32/32 - 0s - loss: 0.8625 - accuracy: 0.5863
# Epoch 243/250
# 32/32 - 0s - loss: 0.8520 - accuracy: 0.5964
# Epoch 244/250
# 32/32 - 0s - loss: 0.8572 - accuracy: 0.5974
# Epoch 245/250
# 32/32 - 0s - loss: 0.8696 - accuracy: 0.5843
# Epoch 246/250
# 32/32 - 0s - loss: 0.8607 - accuracy: 0.5984
# Epoch 247/250
# 32/32 - 0s - loss: 0.8571 - accuracy: 0.5964
# Epoch 248/250
# 32/32 - 0s - loss: 0.8586 - accuracy: 0.5944
# Epoch 249/250
# 32/32 - 0s - loss: 0.8584 - accuracy: 0.6094
# Epoch 250/250
# 32/32 - 0s - loss: 0.8647 - accuracy: 0.6034

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 11/11 - 0s - loss: 0.9594 - accuracy: 0.5663
# Normal Neural Network - Loss: 0.9594460129737854, Accuracy: 0.5662650465965271

# %%
encoded_predictions = model.predict_classes(X_test_scaled)
prediction_labels = label_encoder.inverse_transform(encoded_predictions).tolist()
# Out:
# C:\Users\Tempe\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
y_test1=y_test.tolist()

# print(type(y_test1))
# print(y_test1)
# Out:
# <class 'list'>

# %%
#Compare for percent accuracy
numRight= 0
for n in range (0, len(prediction_labels)):
    if prediction_labels[n]== y_test1[n]:
        numRight += 1   
print(numRight, (100*numRight/len(y_test1)))
# Out:
# 188 56.626506024096386

# %%
#Compare Test with Predictions
dfAccur=pd.DataFrame( )
dfAccur["y_test"]= y_test
dfAccur["y_predictions"]= prediction_labels
dfAccur.head(100)
# Out:
#      y_test y_predictions
# 452   90-94         85-89
# 705   90-94         90-94
# 989   85-89         85-89
# 115   85-89         85-89
# 1152  85-89         85-89
# ...     ...           ...
# 321   85-89         90-94
# 1231  90-94         90-94
# 1047  85-89         85-89
# 111   85-89         85-89
# 1117  85-89         90-94
#
# [100 rows x 2 columns]
